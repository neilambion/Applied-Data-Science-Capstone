# %% [markdown]
# # Part 1

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
page = urllib.request.urlopen(url)

# %%
soup = BeautifulSoup(page, "lxml")

# %%
PostalCode = []
Borough = []
Neighborhood = []

for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        PostalCode.append(cells[0].text.rstrip('\n'))
        Borough.append(cells[1].text.rstrip('\n'))
        Neighborhood.append(cells[2].text.rstrip('\n'))

# %% [markdown]
# ***The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood***

# %%
df = pd.DataFrame({"Postal Code":PostalCode,
                   "Borough":Borough,
                   "Neighborhood":Neighborhood})

# %%
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned
# 1         M2A      Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# ***Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.***

# %%
df_dropna = df[df.Borough != "Not assigned"].reset_index(drop=True)

# %%
df_dropna.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# ***More than one neighborhood can exist in one postal code area***

# %%
df_grp = df_dropna.groupby(["Postal Code", "Borough"], as_index=False).agg(lambda x: ",".join(x))

# %%
df_grp.head()
# Out:
#   Postal Code      Borough                            Neighborhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ***If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.***

# %%
for index, row in df_grp.iterrows():
  if row["Neighborhood"] == "Not Assigned":
    row["Neighborhood"] = row["Borough"]

# %%
df_grp.head()
# Out:
#   Postal Code      Borough                            Neighborhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ***In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.***

# %%
df_grp.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2

# %%
geo_url = "https://cocl.us/Geospatial_data"

# %%
geo_df = pd.read_csv(geo_url)

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ***Use the Geocoder package or the csv file to create the dataframe (Latitude and Longitude)***

# %%
df_mrg = df_grp.merge(geo_df, on="Postal Code", how="left")

# %%
df_mrg.head()
# Out:
#   Postal Code      Borough  ...   Latitude  Longitude
# 0         M1B  Scarborough  ...  43.806686 -79.194353
# 1         M1C  Scarborough  ...  43.784535 -79.160497
# 2         M1E  Scarborough  ...  43.763573 -79.188711
# 3         M1G  Scarborough  ...  43.770992 -79.216917
# 4         M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %% [markdown]
# # Part 3

# %% [markdown]
# # Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data. It is up to you.

# %%
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
import folium

# %% [markdown]
# Use Geopy library to get the latitude and longitude values of Toronto

# %%
address = 'Toronto'
geolocator = Nominatim(user_agent="explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# Create a map of Toronto with neighborhoods superimposed on top.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_mrg['Latitude'], df_mrg['Longitude'], df_mrg['Borough'], df_mrg['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# %% [markdown]
# Boroughs that contain the word toronto

# %%
borough_unique = list(df_mrg.Borough.unique())
borough_toronto = []

for x in borough_unique:
  if "toronto" in x.lower():
    borough_toronto.append(x)

# %%
borough_toronto
# Out:
# ['East Toronto', 'Central Toronto', 'Downtown Toronto', 'West Toronto']

# %%
toronto_data = df_mrg[df_mrg['Borough'].isin(borough_toronto)].reset_index(drop=True)

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'deleted' # your Foursquare ID
CLIENT_SECRET = 'deleted' # your Foursquare Secret
VERSION = '20200518' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: deleted
# CLIENT_SECRET:deleted

# %% [markdown]
# Now, let's get the top 100 venues that are within a radius of 500 meters.

# %%
LIMIT = 100
radius = 500
venues = []

for lat, long, post, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Postal Code'], toronto_data['Borough'], toronto_data['Neighborhood']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        venues.append((
            post, 
            borough,
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
venues_df = pd.DataFrame(venues)
venues_df.columns = ['Postal Code', 'Borough', 'Neighborhood', 'Borough Latitude', 'Borough Longitude', 'Venue Name', 'Venue Latitude', 'Venue Longitude', 'Venue Category']

# %% [markdown]
# Let's check the size of the resulting dataframe

# %%
print(venues_df.shape)
venues_df.head()
# Out:
# (1602, 9)
#   Postal Code       Borough  ... Venue Longitude     Venue Category
# 0         M4E  East Toronto  ...      -79.293942              Trail
# 1         M4E  East Toronto  ...      -79.297734  Health Food Store
# 2         M4E  East Toronto  ...      -79.297215                Pub
# 3         M4E  East Toronto  ...      -79.292869       Neighborhood
# 4         M4K  East Toronto  ...      -79.351265     Cosmetics Shop
#
# [5 rows x 9 columns]

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(venues_df['Venue Category'].unique())))
# Out:
# There are 235 uniques categories.

# %% [markdown]
# Analyze Each Neighborhood

# %%
# one hot encoding
venues_df_onehot = pd.get_dummies(venues_df[['Venue Category']], prefix="", prefix_sep="")

# add postal, borough and neighborhood column back to dataframe
venues_df_onehot['Postal Code'] = venues_df['Postal Code'] 
venues_df_onehot['Borough'] = venues_df['Borough'] 
venues_df_onehot['Neighborhoods'] = venues_df['Neighborhood'] 

# move postal, borough and neighborhood column to the first column
fixed_columns = list(venues_df_onehot.columns[-3:]) + list(venues_df_onehot.columns[:-3])
venues_df_onehot = venues_df_onehot[fixed_columns]

print(venues_df_onehot.shape)
venues_df_onehot.head()
# Out:
# (1602, 238)
#   Postal Code       Borough  ... Women's Store  Yoga Studio
# 0         M4E  East Toronto  ...             0            0
# 1         M4E  East Toronto  ...             0            0
# 2         M4E  East Toronto  ...             0            0
# 3         M4E  East Toronto  ...             0            0
# 4         M4K  East Toronto  ...             0            0
#
# [5 rows x 238 columns]

# %% [markdown]
# Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
venues_grp = venues_df_onehot.groupby(["Postal Code", "Borough", "Neighborhoods"]).mean().reset_index()

print(venues_grp.shape)
venues_grp.head()
# Out:
# (39, 238)
#   Postal Code          Borough  ... Women's Store  Yoga Studio
# 0         M4E     East Toronto  ...           0.0      0.00000
# 1         M4K     East Toronto  ...           0.0      0.02381
# 2         M4L     East Toronto  ...           0.0      0.00000
# 3         M4M     East Toronto  ...           0.0      0.02500
# 4         M4N  Central Toronto  ...           0.0      0.00000
#
# [5 rows x 238 columns]

# %% [markdown]
# Let's put that into a *pandas* dataframe

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
areaColumns = ['Postal Code', 'Borough', 'Neighborhoods']
freqColumns = []
for ind in np.arange(num_top_venues):
    try:
        freqColumns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        freqColumns.append('{}th Most Common Venue'.format(ind+1))
columns = areaColumns+freqColumns

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Postal Code'] = venues_grp['Postal Code']
neighborhoods_venues_sorted['Borough'] = venues_grp['Borough']
neighborhoods_venues_sorted['Neighborhoods'] = venues_grp['Neighborhoods']

for ind in np.arange(venues_grp.shape[0]):
    row_categories = venues_grp.iloc[ind, :].iloc[3:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    neighborhoods_venues_sorted.iloc[ind, 3:] = row_categories_sorted.index.values[0:num_top_venues]

# neighborhoods_venues_sorted.sort_values(freqColumns, inplace=True)
print(neighborhoods_venues_sorted.shape)
neighborhoods_venues_sorted.head()
# Out:
# (39, 13)
#   Postal Code          Borough  ... 9th Most Common Venue 10th Most Common Venue
# 0         M4E     East Toronto  ...        Discount Store            Yoga Studio
# 1         M4K     East Toronto  ...           Pizza Place                 Lounge
# 2         M4L     East Toronto  ...         Burrito Place       Sushi Restaurant
# 3         M4M     East Toronto  ...    Seafood Restaurant         Sandwich Place
# 4         M4N  Central Toronto  ...      Doner Restaurant                Dog Run
#
# [5 rows x 13 columns]

# %% [markdown]
# Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

venues_grp_clustering = venues_grp.drop(["Postal Code", "Borough", "Neighborhoods"], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(venues_grp_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 0, 0, 0, 3, 0, 0, 0, 2, 0], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
print('df_grp: ',df_grp.shape)
print('df_mrg: ',df_mrg.shape)
print('venues_grp: ',venues_grp.shape)
print('neighborhoods_venues_sorted: ',neighborhoods_venues_sorted.shape)
print('venues_grp_clustering: ',venues_grp_clustering.shape)
# Out:
# df_grp:  (103, 3)
# df_mrg:  (103, 5)
# venues_grp:  (39, 238)
# neighborhoods_venues_sorted:  (39, 13)
# venues_grp_clustering:  (39, 235)

# %%
df_mrg.head()
# Out:
#   Postal Code      Borough  ...   Latitude  Longitude
# 0         M1B  Scarborough  ...  43.806686 -79.194353
# 1         M1C  Scarborough  ...  43.784535 -79.160497
# 2         M1E  Scarborough  ...  43.763573 -79.188711
# 3         M1G  Scarborough  ...  43.770992 -79.216917
# 4         M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %%
venues_grp.head()
# Out:
#   Postal Code          Borough  ... Women's Store  Yoga Studio
# 0         M4E     East Toronto  ...           0.0      0.00000
# 1         M4K     East Toronto  ...           0.0      0.02381
# 2         M4L     East Toronto  ...           0.0      0.00000
# 3         M4M     East Toronto  ...           0.0      0.02500
# 4         M4N  Central Toronto  ...           0.0      0.00000
#
# [5 rows x 238 columns]

# %%
df_mrg.head()
# Out:
#   Postal Code      Borough  ...   Latitude  Longitude
# 0         M1B  Scarborough  ...  43.806686 -79.194353
# 1         M1C  Scarborough  ...  43.784535 -79.160497
# 2         M1E  Scarborough  ...  43.763573 -79.188711
# 3         M1G  Scarborough  ...  43.770992 -79.216917
# 4         M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

venues_merged = df_mrg.copy()
venues_merged = venues_merged.join(neighborhoods_venues_sorted.drop(["Borough", "Neighborhoods"], 1).set_index("Postal Code"), on="Postal Code")

venues_merged.head()
# Out:
#   Postal Code      Borough  ... 9th Most Common Venue  10th Most Common Venue
# 0         M1B  Scarborough  ...                   NaN                     NaN
# 1         M1C  Scarborough  ...                   NaN                     NaN
# 2         M1E  Scarborough  ...                   NaN                     NaN
# 3         M1G  Scarborough  ...                   NaN                     NaN
# 4         M1H  Scarborough  ...                   NaN                     NaN
#
# [5 rows x 16 columns]

# %%
venues_merged.shape
# Out:
# (103, 16)

# %%
venues_merged.sort_values(['Cluster Labels'], inplace=True)

# %%
venues_merged.head()
# Out:
#    Postal Code           Borough  ... 9th Most Common Venue  10th Most Common Venue
# 59         M5J  Downtown Toronto  ...            Restaurant      Italian Restaurant
# 60         M5K  Downtown Toronto  ...   American Restaurant     Sporting Goods Shop
# 61         M5L  Downtown Toronto  ...    Italian Restaurant     Japanese Restaurant
# 65         M5R   Central Toronto  ...           Flower Shop                     Pub
# 66         M5S  Downtown Toronto  ...    Chinese Restaurant            Dessert Shop
#
# [5 rows x 16 columns]

# %%
venues_merged.dropna(inplace=True)
venues_merged.shape
# Out:
# (39, 16)

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, post, bor, poi, cluster in zip(venues_merged['Latitude'], venues_merged['Longitude'], venues_merged['Postal Code'], venues_merged['Borough'], venues_merged['Neighborhood'], venues_merged['Cluster Labels']):
    label = folium.Popup('{} ({}): {} - Cluster {}'.format(bor, post, poi, cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)

# %%
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine Clusters

# %% [markdown]
# Cluster 1

# %%
venues_merged.loc[venues_merged['Cluster Labels'] == 0, venues_merged.columns[[1] + list(range(5, venues_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 59  Downtown Toronto  ...      Italian Restaurant
# 60  Downtown Toronto  ...     Sporting Goods Shop
# 61  Downtown Toronto  ...     Japanese Restaurant
# 65   Central Toronto  ...                     Pub
# 66  Downtown Toronto  ...            Dessert Shop
# 67  Downtown Toronto  ...           Burrito Place
# 68  Downtown Toronto  ...           Boat or Ferry
# 69  Downtown Toronto  ...                     Gym
# 70  Downtown Toronto  ...        Asian Restaurant
# 75  Downtown Toronto  ...              Baby Store
# 76      West Toronto  ...                    Café
# 77      West Toronto  ...                Boutique
# 78      West Toronto  ...            Intersection
# 82      West Toronto  ...     Arts & Crafts Store
# 83      West Toronto  ...           Movie Theater
# 84      West Toronto  ...             Yoga Studio
# 85  Downtown Toronto  ...                Beer Bar
# 58  Downtown Toronto  ...        Sushi Restaurant
# ...

# %% [markdown]
# Cluster 2

# %%
venues_merged.loc[venues_merged['Cluster Labels'] == 1, venues_merged.columns[[1] + list(range(5, venues_merged.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 63  Central Toronto  ...                 Dog Run
#
# [1 rows x 12 columns]

# %% [markdown]
# Cluster 3

# %%
venues_merged.loc[venues_merged['Cluster Labels'] == 2, venues_merged.columns[[1] + list(range(5, venues_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 48   Central Toronto  ...     Distribution Center
# 64   Central Toronto  ...                 Dog Run
# 50  Downtown Toronto  ...     Distribution Center
#
# [3 rows x 12 columns]

# %% [markdown]
# Cluster 4

# %%
venues_merged.loc[venues_merged['Cluster Labels'] == 3, venues_merged.columns[[1] + list(range(5, venues_merged.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 44  Central Toronto  ...                 Dog Run
#
# [1 rows x 12 columns]

# %% [markdown]
# Cluster 5

# %%
venues_merged.loc[venues_merged['Cluster Labels'] == 4, venues_merged.columns[[1] + list(range(5, venues_merged.shape[1]))]]
# Out:
#          Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 37  East Toronto             4.0  ...        Discount Store            Yoga Studio
#
# [1 rows x 12 columns]

# %% [markdown]
# Observations:

# %% [markdown]
# Cluster 1: Common venues are Coffee shops and Food Restaurant

# %% [markdown]
# Cluster 2: Common venues are Home Service and Garden

# %% [markdown]
# Cluster 3: Common venues are Parks and Playground

# %% [markdown]
# Cluster 4: Common venues are Parks and Swim school

# %% [markdown]
# Cluster 5: Common venues are Trails
